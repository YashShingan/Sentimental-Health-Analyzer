# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

df = pd.read_csv("../data/social_media_dataset.csv")

sns.histplot(df["avg_daily_usage_hours"])
plt.title("Daily Social Media Usage")
plt.show()

sns.boxplot(x="mental_health_risk", y="avg_daily_usage_hours", data=df)


joblib.dump(model, "models/mental_health_model.pkl")
joblib.dump(X.columns, "models/model_columns.pkl")
